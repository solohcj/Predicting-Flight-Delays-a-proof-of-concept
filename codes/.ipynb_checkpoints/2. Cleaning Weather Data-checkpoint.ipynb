# %% [markdown]
# <img src="../images/airplane-symbol.jpg" style="float: left; margin: 20px;" width="50" height="50">
# #  Predicting Flight Delays (<i>a Proof-of-Concept</i>)
#
# Author: Solomon Heng
#
# ---

# %% [markdown]
# # (2) Cleaning Weather Data
#
# ## Processes covered in this notebook:
# 1. [Importing Extracted METAR data](#(1)-Importing-Extracted-METAR-data)
# 2. [Cleaning dew_point](#(2)-Cleaning-dew_point)
# 3. [Cleaning temp](#(3)-Cleaning-temp)
# 4. [Cleaning visibility](#(4)-Cleaning-visibility)
# 5. [Cleaning winddirspd](#(5)-Cleaning-winddirspd)
# 6. [Cleaning QNH](#(6)-Cleaning-QNH)
# 7. [Cleaning wind variation](#(7)-Cleaning-wind-variation)
# 8. [Final checks and exporting dataset](#(8)-Final-checks-and-exporting-dataset)

# %%
import re
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# ### (1) Importing Extracted METAR data
#
# ---

# %%
wx = pd.read_csv('../datasets/unclean_wx.csv')

# %%
wx.head()
# Out:
#    month  year  day  hour  min    QNH dew_point lightning low_intensity rain  \
# 0      1  2015    1     0   52  A3037       /01         0             0    0
# 1      1  2015    1     1   52  A3037       /00         0             0    0
# 2      1  2015    1     2   52  A3036       /00         0             0    0
# 3      1  2015    1     3   52  A3037      /M01         0             0    0
# 4      1  2015    1     4   52  A3035      /M01         0             0    0
#
#   shower snow squall temp thunderyshower vicinity visibility wind_variation  \
# 0      0    0      0  05/              0        0      10SM               0
# 1      0    0      0  04/              0        0      10SM               0
# 2      0    0      0  04/              0        0      10SM               0
# 3      0    0      0  03/              0        0      10SM               0
# 4      0    0      0  03/              0        0      10SM               0
#
#   winddirspd
# 0    33005KT
# 1    31004KT
# 2    00000KT
# 3    32005KT
# 4    32006KT

# %% [markdown]
# ---
# ### (2) Cleaning dew_point
#
# ---

# %%
wx['dew_point'] = [i.replace('/', '') for i in wx['dew_point']]
wx['dew_point'] = [i.replace('M', '-') for i in wx['dew_point']]

# %%
# Converting to correct dtype

wx['dew_point'] = wx['dew_point'].astype(int)

# %%
wx.head(2)
# Out:
#    month  year  day  hour  min    QNH  dew_point lightning low_intensity rain  \
# 0      1  2015    1     0   52  A3037          1         0             0    0
# 1      1  2015    1     1   52  A3037          0         0             0    0
#
#   shower snow squall temp thunderyshower vicinity visibility wind_variation  \
# 0      0    0      0  05/              0        0      10SM               0
# 1      0    0      0  04/              0        0      10SM               0
#
#   winddirspd
# 0    33005KT
# 1    31004KT

# %% [markdown]
# ---
# ### (3) Cleaning temp
#
# ---

# %%
wx['temp'] = [i.replace('/', '') for i in wx['temp']]
wx['temp'] = [i.replace('M', '-') for i in wx['temp']]

# %%
# Converting to correct dtype

wx['temp'] = wx['temp'].astype(int)

# %%
wx.head(2)
# Out:
#    month  year  day  hour  min    QNH  dew_point lightning low_intensity rain  \
# 0      1  2015    1     0   52  A3037          1         0             0    0
# 1      1  2015    1     1   52  A3037          0         0             0    0
#
#   shower snow squall  temp thunderyshower vicinity visibility wind_variation  \
# 0      0    0      0     5              0        0      10SM               0
# 1      0    0      0     4              0        0      10SM               0
#
#   winddirspd
# 0    33005KT
# 1    31004KT

# %% [markdown]
# ---
# ### (4) Cleaning visibility
#
# We will be converting all of them with Statute Mile as base unit
#
# ---

# %%
wx.visibility.unique()
# Out:
# array(['10SM ', '1/2SM ', '3/4SM ', '1/4SM ', '16SM ', '1/8SM '],
#       dtype=object)

# %%
wx[wx.visibility == '16SM ']
# Out:
#       month  year  day  hour  min    QNH  dew_point lightning low_intensity  \
# 1495      3  2015    4     6   52  A3007         16       LTG             -
# 1496      3  2015    4     7   52  A3006         16       LTG             -
#
#      rain shower snow squall  temp thunderyshower vicinity visibility  \
# 1495   RA     SH   SN      0    10             TS       VC      16SM
# 1496   RA     SH   SN      0    10             TS       VC      16SM
#
#      wind_variation winddirspd
# 1495       040V110     14003KT
# 1496       040V110     15004KT

# %%
wx.iloc[1846,:].visibility
# Out:
# '10SM '

# %%
wx['visibility'] = [i.replace('SM', '') for i in wx['visibility']]
wx['visibility'] = [i.replace('1/2', '0.5') for i in wx['visibility']]
wx['visibility'] = [i.replace('3/4', '0.75') for i in wx['visibility']]
wx['visibility'] = [i.replace('1/4', '0.25') for i in wx['visibility']]
wx['visibility'] = [i.replace('1/8', '0.125') for i in wx['visibility']]

# %%
wx.visibility.unique()
# Out:
# array(['10 ', '0.5 ', '0.75 ', '0.25 ', '16 ', '0.125 '], dtype=object)

# %%
# Converting to correct dtype

wx['visibility'] = wx['visibility'].astype(float)

# %%
wx.head()
# Out:
#    month  year  day  hour  min    QNH  dew_point lightning low_intensity rain  \
# 0      1  2015    1     0   52  A3037          1         0             0    0
# 1      1  2015    1     1   52  A3037          0         0             0    0
# 2      1  2015    1     2   52  A3036          0         0             0    0
# 3      1  2015    1     3   52  A3037         -1         0             0    0
# 4      1  2015    1     4   52  A3035         -1         0             0    0
#
#   shower snow squall  temp thunderyshower vicinity  visibility wind_variation  \
# 0      0    0      0     5              0        0        10.0              0
# 1      0    0      0     4              0        0        10.0              0
# 2      0    0      0     4              0        0        10.0              0
# 3      0    0      0     3              0        0        10.0              0
# 4      0    0      0     3              0        0        10.0              0
#
#   winddirspd
# 0    33005KT
# 1    31004KT
# 2    00000KT
# 3    32005KT
# 4    32006KT

# %% [markdown]
# ---
# ### (5) Cleaning winddirspd
#
# We will be splitting the information up into:
# 1. Wind Direction _(winddir)_
# 2. Wind Speed _(windspd)_
# 3. Wind Gusts _(windgust)_
#
# ---

# %%
wx.winddirspd.unique()
# Out:
# array(['33005KT', '31004KT', '00000KT', '32005KT', '32006KT', '33004KT',
#        '33007KT', '31003KT', '31006KT', 'VRB03KT', '26003KT', '29004KT',
#        '30003KT', '28005KT', '30006KT', '34004KT', '34005KT', '35006KT',
#        '03005KT', '20003KT', '30004KT', '15003KT', '33006KT', '04004KT',
#        'COR 000', '06003KT', '04006KT', '03007KT', '07006KT', '11004KT',
#        '11006KT', '14006KT', '13006KT', '12006KT', '10005KT', '12007KT',
#        '10006KT', '11009KT', '10008KT', '09009KT', '11007KT', '11008KT',
#        '10009KT', '12010KT', '12009KT', '12008KT', '11005KT', '09006KT',
#        '10007KT', '14007KT', '18008KT', '20008KT', '17005KT', '17006KT',
#        '16005KT', '13004KT', '24012G2', '20007KT', '19005KT', '19008KT',
#        '25005KT', '24008KT', '24010KT', '24009G1', '26013G2', '26012G2',
#        '27014G1', '29016G2', '30015G2', '31014G2', '29013G1', '29014G2',
#        '31013G2', '32011KT', '32011G1', '33014KT', '33019G2', '33014G2',
#        'COR 330', '34012KT', '33010G2', '32014KT', '34010KT', '33013G2',
#        '33012KT', '32009KT', '33010KT', '34008KT', '33008KT', '02006KT',
#        '31005KT', '28006KT', '27005KT', '28007KT', '27011G1', '29008KT',
#        '29012G2', '31017G2', '30013G2', '28011KT', '27009KT', '31007KT',
#        '31018KT', '30016G1', '33015KT', '22012KT', 'COR 130', '07014G1',
#        '16012G1', '12012KT', '14011KT', '16014G1', '17011G1', '18010G1',
#        '17013KT', '30017KT', '14010G1', '15012KT', '16013KT', '17012G1',
#        '18011KT', '20013KT', '22008G1', '17015G2', '16017G2', '17019G2',
#        '18008G1', '18013G2', '19012G1', '19012KT', '01022G2', '15011G2',
#        '16021G2', '16016G2', '15016G2'], dtype=object)

# %%
wx[wx['winddirspd'].str.contains('COR', na=False)].head()
# Out:
#      month  year  day  hour  min    QNH  dew_point lightning low_intensity  \
# 40       1  2015    2    16   52  A3032          7         0             -
# 107      1  2015    5    11   52  A3041         -2       LTG             -
# 327      1  2015   14    15   52  A3028          3       LTG             -
# 410      1  2015   18     2   52  A3013          1       LTG             -
# 836      2  2015    4    20   52  A3014         -4       LTG             -
#
#     rain shower snow squall  temp thunderyshower vicinity  visibility  \
# 40    RA      0    0      0     8              0       VC        10.0
# 107   RA      0    0      0     4             TS       VC        10.0
# 327   RA      0    0      0     5             TS       VC         0.5
# 410   RA      0   SN      0     9             TS       VC        10.0
# 836   RA     SH   SN      0    10             TS       VC        10.0
#
#     wind_variation winddirspd
# 40               0    COR 000
# 107       003V007     COR 330
# 327       003V006     COR 350
# 410       008V011     COR 150
# 836       004V008     COR 180

# %%
wx.iloc[105:109,]
# Out:
#      month  year  day  hour  min    QNH  dew_point lightning low_intensity  \
# 105      1  2015    5     9   52  A3037         -1       LTG             -
# 106      1  2015    5    10   52  A3040         -1       LTG             -
# 107      1  2015    5    11   52  A3041         -2       LTG             -
# 108      1  2015    5    12   52  A3045         -2       LTG             -
#
#     rain shower snow squall  temp thunderyshower vicinity  visibility  \
# 105   RA      0    0      0     4             TS       VC        10.0
# 106   RA      0    0      0     4             TS       VC        10.0
# 107   RA      0    0      0     4             TS       VC        10.0
# 108   RA      0    0      0     3             TS       VC        10.0
#
#     wind_variation winddirspd
# 105       003V007     33019G2
# 106       003V007     33014G2
# 107       003V007     COR 330
# 108       003V007     34012KT

# %%
re.findall(r'\d{3}', wx['winddirspd'][0])[0]
# Out:
# '330'

# %%
# Imputing nan with 999 for subsequent parsing

wx['winddirspd'].fillna('999', inplace=True)

# %%
wx['winddir'] = [re.findall(r'\d{3}', i) for i in wx['winddirspd']]
wx['windspd'] = [re.findall(r'\d{2}G|\d{2}KT', i) for i in wx['winddirspd']]
wx['windgust'] = [re.findall(r'G\d+', i) for i in wx['winddirspd']]

# %%
wx.head()
# Out:
#    month  year  day  hour  min    QNH  dew_point lightning low_intensity rain  \
# 0      1  2015    1     0   52  A3037          1         0             0    0
# 1      1  2015    1     1   52  A3037          0         0             0    0
# 2      1  2015    1     2   52  A3036          0         0             0    0
# 3      1  2015    1     3   52  A3037         -1         0             0    0
# 4      1  2015    1     4   52  A3035         -1         0             0    0
#
#    ... squall temp thunderyshower  vicinity visibility wind_variation  \
# 0  ...      0    5              0         0       10.0              0
# 1  ...      0    4              0         0       10.0              0
# 2  ...      0    4              0         0       10.0              0
# 3  ...      0    3              0         0       10.0              0
# 4  ...      0    3              0         0       10.0              0
#
#    winddirspd winddir windspd windgust
# 0     33005KT   [330]  [05KT]       []
# 1     31004KT   [310]  [04KT]       []
# 2     00000KT   [000]  [00KT]       []
# 3     32005KT   [320]  [05KT]       []
# 4     32006KT   [320]  [06KT]       []
#
# [5 rows x 22 columns]

# %%
def extract_from_list(x):
    """Defining function to help us extract the string values from the list within the cell"""
    try:
        return x[0]
    except:
        pass

# %%
wx['windspd'] = wx['windspd'].apply(extract_from_list)
wx['winddir'] = wx['winddir'].apply(extract_from_list)
wx['windgust'] = wx['windgust'].apply(extract_from_list)

# %%
# Imputing nan with 999 for subsequent parsing of wind speed and dir

wx['windspd'].fillna('999', inplace=True)
wx['winddir'].fillna('999', inplace=True) # possibility of new nans as if wind is VRB, it would not be captured by regex above

# %%
# Dropping the units 'KT's from the wind speed feature
wx['windspd'] = [i.replace('KT', '') for i in wx['windspd']]
wx['windspd'] = [i.replace('G', '') for i in wx['windspd']]

# Replacing null with 0 as there is no gust
wx['windgust'].fillna(0, inplace=True)

# %%
wx.head()
# Out:
#    month  year  day  hour  min    QNH  dew_point lightning low_intensity rain  \
# 0      1  2015    1     0   52  A3037          1         0             0    0
# 1      1  2015    1     1   52  A3037          0         0             0    0
# 2      1  2015    1     2   52  A3036          0         0             0    0
# 3      1  2015    1     3   52  A3037         -1         0             0    0
# 4      1  2015    1     4   52  A3035         -1         0             0    0
#
#    ... squall temp thunderyshower  vicinity visibility wind_variation  \
# 0  ...      0    5              0         0       10.0              0
# 1  ...      0    4              0         0       10.0              0
# 2  ...      0    4              0         0       10.0              0
# 3  ...      0    3              0         0       10.0              0
# 4  ...      0    3              0         0       10.0              0
#
#    winddirspd winddir windspd windgust
# 0     33005KT     330      05        0
# 1     31004KT     310      04        0
# 2     00000KT     000      00        0
# 3     32005KT     320      05        0
# 4     32006KT     320      06        0
#
# [5 rows x 22 columns]

# %% [markdown]
# 'COR' means corrected observations and we will not have the actual readings of wind speed if we have this. As such, if we have a corrected observation, we will the speed with the next recorded value.
#
# We will also do the same _(take average of previous and next hour)_ for all other wind null values.

# %%
wx['windspd'] = wx['windspd'].astype(int)
wx['winddir'] = wx['winddir'].astype(int)

# %%
wx['windspd'] = [np.nan if i == 999 else i for i in wx['windspd']]
wx['winddir'] = [np.nan if i == 999 else i for i in wx['winddir']]

# %%
wx[wx['windspd'].isnull()].head()
# Out:
#      month  year  day  hour  min    QNH  dew_point lightning low_intensity  \
# 40       1  2015    2    16   52  A3032          7         0             -
# 107      1  2015    5    11   52  A3041         -2       LTG             -
# 327      1  2015   14    15   52  A3028          3       LTG             -
# 410      1  2015   18     2   52  A3013          1       LTG             -
# 836      2  2015    4    20   52  A3014         -4       LTG             -
#
#     rain  ... squall temp thunderyshower  vicinity visibility wind_variation  \
# 40    RA  ...      0    8              0        VC       10.0              0
# 107   RA  ...      0    4             TS        VC       10.0       003V007
# 327   RA  ...      0    5             TS        VC        0.5       003V006
# 410   RA  ...      0    9             TS        VC       10.0       008V011
# 836   RA  ...      0   10             TS        VC       10.0       004V008
#
#      winddirspd winddir windspd  windgust
# 40      COR 000     0.0     NaN         0
# 107     COR 330   330.0     NaN         0
# 327     COR 350   350.0     NaN         0
# 410     COR 150   150.0     NaN         0
# 836     COR 180   180.0     NaN         0
#
# [5 rows x 22 columns]

# %%
wx['windspd'].fillna(method='bfill', inplace=True)
wx['winddir'].fillna(method='bfill', inplace=True)

# %%
# Dropping winddirspd feature as we no longer need it

wx.drop('winddirspd', axis=1, inplace=True)

# %%
pd.set_option('display.max_columns', 40)
wx.head()
# Out:
#    month  year  day  hour  min    QNH  dew_point lightning low_intensity rain  \
# 0      1  2015    1     0   52  A3037          1         0             0    0
# 1      1  2015    1     1   52  A3037          0         0             0    0
# 2      1  2015    1     2   52  A3036          0         0             0    0
# 3      1  2015    1     3   52  A3037         -1         0             0    0
# 4      1  2015    1     4   52  A3035         -1         0             0    0
#
#   shower snow squall  temp thunderyshower vicinity  visibility wind_variation  \
# 0      0    0      0     5              0        0        10.0              0
# 1      0    0      0     4              0        0        10.0              0
# 2      0    0      0     4              0        0        10.0              0
# 3      0    0      0     3              0        0        10.0              0
# 4      0    0      0     3              0        0        10.0              0
#
#    winddir  windspd windgust
# 0    330.0      5.0        0
# 1    310.0      4.0        0
# 2      0.0      0.0        0
# 3    320.0      5.0        0
# 4    320.0      6.0        0

# %% [markdown]
# ---
# ### (6) Cleaning QNH
#
# _A3006 indicates the altimeter setting is 30.06 inHg (1,018 hPa) - Wikipedia_
#
# ---

# %%
# Correcting the QNH feature

wx['QNH'] = [i.replace('A', '') for i in wx['QNH']]

# %%
wx['QNH'] = wx['QNH'].astype(int)
wx['QNH'] = [i/100 for i in wx['QNH']]

# %%
wx.head()
# Out:
#    month  year  day  hour  min    QNH  dew_point lightning low_intensity rain  \
# 0      1  2015    1     0   52  30.37          1         0             0    0
# 1      1  2015    1     1   52  30.37          0         0             0    0
# 2      1  2015    1     2   52  30.36          0         0             0    0
# 3      1  2015    1     3   52  30.37         -1         0             0    0
# 4      1  2015    1     4   52  30.35         -1         0             0    0
#
#   shower snow squall  temp thunderyshower vicinity  visibility wind_variation  \
# 0      0    0      0     5              0        0        10.0              0
# 1      0    0      0     4              0        0        10.0              0
# 2      0    0      0     4              0        0        10.0              0
# 3      0    0      0     3              0        0        10.0              0
# 4      0    0      0     3              0        0        10.0              0
#
#    winddir  windspd windgust
# 0    330.0      5.0        0
# 1    310.0      4.0        0
# 2      0.0      0.0        0
# 3    320.0      5.0        0
# 4    320.0      6.0        0

# %% [markdown]
# ---
# ### (7) Cleaning wind variation
#
# We shall opt to drop the wind variation feature as it "would not serve much purpose in the model. It would be too specific and technically every aircraft would experience a different variation (even diff variation for different approaches) if we were to take it into account, making it nearly impossible to determine what an aircraft actually experiences. I felt that using the averaged out wind direction ('winddir') would be more meaningful.
#
# ---

# %%
wx.drop('wind_variation', axis=1, inplace=True)

# %% [markdown]
# ---
# ### (8) Final checks and exporting dataset
#
# ---

# %%
# Checking for duplicates

wx[wx.duplicated(subset=['month', 'day', 'hour'])]
# Out:
#       month  year  day  hour  min    QNH  dew_point lightning low_intensity  \
# 1179      2  2015   19     2   52  30.15        -13       LTG             -
# 3280      5  2015   17    14   52  30.28         18       LTG             -
# 4016      6  2015   17    10   52  30.13         21       LTG             -
# 4096      6  2015   20    17   52  30.06         22       LTG             -
# 4194      6  2015   24    21   52  30.13         20       LTG             -
# 4345      7  2015    1     5   52  30.04         18       LTG             -
# 4868      7  2015   23     0   52  29.95         21       LTG             -
# 5629      8  2015   23    16   52  30.03         21       LTG             -
# 5639      8  2015   24     2   52  29.99         20       LTG             -
# 5648      8  2015   24    10   52  29.98         20       LTG             -
# 5757      8  2015   28    22   52  30.11         18       LTG             -
# 5812      8  2015   31     4   52  30.11         18       LTG             -
# 6091      9  2015   11    18   52  29.90         18       LTG             -
# 6184      9  2015   15    14   52  30.35         14       LTG             -
# 6382      9  2015   23    19   52  30.10         17       LTG             -
# 6384      9  2015   23    20   52  30.09         16       LTG             -
# 6393      9  2015   24     4   52  30.12         16       LTG             -
# 6400      9  2015   24    10   52  30.11         13       LTG             -
# 6402      9  2015   24    11   52  30.13         13       LTG             -
# 6446      9  2015   26     6   52  30.00         18       LTG             -
# 6511      9  2015   28    22   52  29.95         21       LTG             -
# 6542      9  2015   30     4   52  29.84         21       LTG             -
# 6549      9  2015   30    10   52  29.82         20       LTG             -
# 6598     10  2015    2    10   52  29.80         14       LTG             -
# 6619     10  2015    3     7   52  29.72         13       LTG             -
# 6622     10  2015    3     9   52  29.69         13       LTG             -
# 6834     10  2015   12     4   52  29.95         13       LTG             -
# 6859     10  2015   13     4   52  29.82         12       LTG             -
# 6890     10  2015   14    10   52  29.96          7       LTG             -
# 6892     10  2015   14    11   52  29.97          7       LTG             -
# 6904     10  2015   14    22   52  30.00          8       LTG             -
# 6929     10  2015   15    22   52  30.10         10       LTG             -
# 6932     10  2015   16     0   52  30.13         11       LTG             -
# 7027     10  2015   19    22   52  30.37          1       LTG             -
# 7058     10  2015   21     4   52  30.32          6       LTG             -
# 7065     10  2015   21    10   52  30.34          4       LTG             -
# 7090     10  2015   22    10   52  30.30          9       LTG             -
# 7097     10  2015   22    16   52  30.33         15       LTG             -
# 7130     10  2015   24     0   52  30.17         14       LTG             -
# 7147     10  2015   24    16   52  30.20         14       LTG             -
# 7149     10  2015   24    17   52  30.18         15       LTG             -
# 7168     10  2015   25    11   52  30.18         16       LTG             -
# 7170     10  2015   25    12   52  30.17         40       LTG             -
# 7277     10  2015   29    22   52  29.90         13       LTG             -
# 7438     11  2015    5    14   52  30.28         16       LTG             -
# 7622     11  2015   13     5   52  30.06          4       LTG             -
# 7653     11  2015   14    11   52  30.31         -5       LTG             -
# 8441     12  2015   17     7   52  29.84         13       LTG             -
#
#      rain shower snow squall  temp thunderyshower vicinity  visibility  \
# 1179   RA     SH   SN      0    -3             TS       VC       10.00
# 3280   RA     SH   SN      0    24             TS       VC       10.00
# 4016   RA     SH   SN      0    25             TS       VC       10.00
# 4096   RA     SH   SN      0    26             TS       VC       10.00
# 4194   RA     SH   SN      0    22             TS       VC        0.50
# 4345   RA     SH   SN      0    22             TS       VC       10.00
# 4868   RA     SH   SN      0    26             TS       VC       10.00
# 5629   RA     SH   SN     SQ    27             TS       VC       10.00
# 5639   RA     SH   SN     SQ    26             TS       VC       10.00
# 5648   RA     SH   SN     SQ    22             TS       VC       10.00
# 5757   RA     SH   SN     SQ    27             TS       VC       10.00
# 5812   RA     SH   SN     SQ    21             TS       VC       10.00
# 6091   RA     SH   SN     SQ    29             TS       VC       10.00
# 6184   RA     SH   SN     SQ    22             TS       VC       10.00
# 6382   RA     SH   SN     SQ    27             TS       VC       10.00
# 6384   RA     SH   SN     SQ    26             TS       VC       10.00
# 6393   RA     SH   SN     SQ    21             TS       VC       10.00
# 6400   RA     SH   SN     SQ    19             TS       VC       10.00
# 6402   RA     SH   SN     SQ    19             TS       VC       10.00
# 6446   RA     SH   SN     SQ    19             TS       VC        0.75
# 6511   RA     SH   SN     SQ    23             TS       VC       10.00
# 6542   RA     SH   SN     SQ    22             TS       VC       10.00
# 6549   RA     SH   SN     SQ    21             TS       VC        0.50
# 6598   RA     SH   SN     SQ    16             TS       VC        0.50
# 6619   RA     SH   SN     SQ    14             TS       VC       10.00
# 6622   RA     SH   SN     SQ    14             TS       VC       10.00
# 6834   RA     SH   SN     SQ    15             TS       VC       10.00
# 6859   RA     SH   SN     SQ    17             TS       VC       10.00
# 6890   RA     SH   SN     SQ    11             TS       VC       10.00
# 6892   RA     SH   SN     SQ    11             TS       VC       10.00
# 6904   RA     SH   SN     SQ    22             TS       VC       10.00
# 6929   RA     SH   SN     SQ    24             TS       VC       10.00
# 6932   RA     SH   SN     SQ    21             TS       VC       10.00
# 7027   RA     SH   SN     SQ    15             TS       VC       10.00
# 7058   RA     SH   SN     SQ    13             TS       VC       10.00
# 7065   RA     SH   SN     SQ    11             TS       VC       10.00
# 7090   RA     SH   SN     SQ    13             TS       VC       10.00
# 7097   RA     SH   SN     SQ    23             TS       VC       10.00
# 7130   RA     SH   SN     SQ    20             TS       VC       10.00
# 7147   RA     SH   SN     SQ    23             TS       VC       10.00
# 7149   RA     SH   SN     SQ    23             TS       VC       10.00
# 7168   RA     SH   SN     SQ    17             TS       VC        0.50
# 7170   RA     SH   SN     SQ    17             TS       VC        0.50
# 7277   RA     SH   SN     SQ    18             TS       VC       10.00
# 7438   RA     SH   SN     SQ    17             TS       VC        0.50
# 7622   RA     SH   SN     SQ    11             TS       VC       10.00
# 7653   RA     SH   SN     SQ     4             TS       VC       10.00
# 8441   RA     SH   SN     SQ    14             TS       VC        0.50
#
#       winddir  windspd windgust
# 1179    310.0     19.0       G2
# 3280    160.0      5.0        0
# 4016    300.0      5.0        0
# 4096    290.0      6.0        0
# 4194    220.0      9.0        0
# 4345    250.0      6.0        0
# 4868     10.0      6.0        0
# 5629    320.0      3.0        0
# 5639    350.0      4.0        0
# 5648    310.0      6.0        0
# 5757    120.0      6.0        0
# 5812     70.0      9.0        0
# 6091    290.0      8.0        0
# 6184    100.0      8.0        0
# 6382     80.0      9.0       G1
# 6384     60.0      8.0       G1
# 6393     60.0      8.0        0
# 6400     70.0     14.0        0
# 6402     70.0     12.0        0
# 6446     70.0      5.0        0
# 6511     90.0      8.0        0
# 6542    310.0      0.0        0
# 6549    340.0      3.0        0
# 6598     50.0     12.0        0
# 6619     70.0     12.0        0
# 6622     40.0      8.0        0
# 6834      0.0      0.0        0
# 6859    220.0      7.0        0
# 6890    240.0      3.0        0
# 6892    260.0      3.0        0
# 6904    320.0      4.0        0
# 6929      0.0      3.0        0
# 6932    200.0      3.0        0
# 7027    120.0      8.0        0
# 7058     90.0      4.0        0
# 7065     60.0      6.0        0
# 7090     80.0      4.0        0
# 7097    150.0      4.0        0
# 7130    150.0      3.0        0
# 7147    160.0      8.0        0
# 7149    170.0      5.0        0
# 7168     90.0      4.0        0
# 7170    100.0      7.0        0
# 7277    330.0      4.0        0
# 7438    100.0      8.0        0
# 7622    300.0      8.0        0
# 7653    340.0     10.0        0
# 8441     90.0      5.0        0

# %% [markdown]
# Found some anomalies later on and came back to zoom in on them here

# %%
wx.iloc[1177:1182,]
# Out:
#       month  year  day  hour  min    QNH  dew_point lightning low_intensity  \
# 1177      2  2015   19     1   52  30.12        -12       LTG             -
# 1178      2  2015   19     2    0  30.12        -12       LTG             -
# 1179      2  2015   19     2   52  30.15        -13       LTG             -
# 1180      2  2015   19     3   52  30.18        -14       LTG             -
# 1181      2  2015   19     4   52  30.19        -14       LTG             -
#
#      rain shower snow squall  temp thunderyshower vicinity  visibility  \
# 1177   RA     SH   SN      0    -3             TS       VC        10.0
# 1178   RA     SH   SN      0    -3             TS       VC        10.0
# 1179   RA     SH   SN      0    -3             TS       VC        10.0
# 1180   RA     SH   SN      0    -4             TS       VC        10.0
# 1181   RA     SH   SN      0    -5             TS       VC        10.0
#
#       winddir  windspd windgust
# 1177    310.0     18.0       G3
# 1178    310.0     19.0        0
# 1179    310.0     19.0       G2
# 1180    300.0     17.0       G2
# 1181    330.0     18.0       G2

# %%
wx.iloc[3277:3283,]
# Out:
#       month  year  day  hour  min    QNH  dew_point lightning low_intensity  \
# 3277      5  2015   17    12   52  30.28         16       LTG             -
# 3278      5  2015   17    13   52  30.28         17       LTG             -
# 3279      5  2015   17    14    0  30.28         17       LTG             -
# 3280      5  2015   17    14   52  30.28         18       LTG             -
# 3281      5  2015   17    15   52  30.28         18       LTG             -
# 3282      5  2015   17    16   52  30.27         18       LTG             -
#
#      rain shower snow squall  temp thunderyshower vicinity  visibility  \
# 3277   RA     SH   SN      0    21             TS       VC        10.0
# 3278   RA     SH   SN      0    23             TS       VC        10.0
# 3279   RA     SH   SN      0    23             TS       VC        10.0
# 3280   RA     SH   SN      0    24             TS       VC        10.0
# 3281   RA     SH   SN      0    26             TS       VC        10.0
# 3282   RA     SH   SN      0    27             TS       VC        10.0
#
#       winddir  windspd windgust
# 3277    180.0      4.0        0
# 3278    170.0      7.0        0
# 3279    160.0      5.0        0
# 3280    160.0      5.0        0
# 3281    160.0      3.0        0
# 3282    160.0      6.0        0

# %%
wx['min'].unique()
# Out:
# array([52,  0], dtype=int64)

# %% [markdown]
# Notice how there is a 0 min in some columns. METARs in US are supposed to be releases on the 52nd minute, as such we will treat them as anomalies _(probably wrongly keyed in data)_ and drop all 0 min readings.

# %%
wx.shape
# Out:
# (8794, 20)

# %%
wx = wx[wx['min'] != 0]

# %%
wx.shape
# Out:
# (8739, 20)

# %% [markdown]
# We if we have the METAR every hour for the entire year of 365 days, we would have 8760 rows of readings, but notice that after we dropped the duplicates, we only have 3739 rows. It is likely that there are missing rows of data within for certain hours.
#
# We will continue with 8739 rows of data as of now and later on drop the combined data with no weather.

# %%
wx.isnull().sum()
# Out:
# month             0
# year              0
# day               0
# hour              0
# min               0
# QNH               0
# dew_point         0
# lightning         0
# low_intensity     0
# rain              0
# shower            0
# snow              0
# squall            0
# temp              0
# thunderyshower    0
# vicinity          0
# visibility        0
# winddir           0
# windspd           0
# windgust          0
# dtype: int64

# %%
wx.to_csv('../datasets/cleaned_wx.csv', index=False)
